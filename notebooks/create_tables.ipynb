# %%
#import pandas and sqlite
import pandas as pd
import sqlite3 as sl#connecct to database object
conn = sl.connect('Elections.db')
c = conn.cursor()

# %%
c.execute('DROP TABLE IF EXISTS fivethirtyeight')
c.execute('CREATE TABLE fivethirtyeight (cycle str, branch str, type str, matchup str, forecastdate datetime, state str, startdate datetime, enddate datetime, pollster str, grade str, samplesize str, population str, poll_wt str, rawpoll_clinton, rawpoll_trump, rawpoll_johnson, rawpoll_mcmullin, adjpoll_clinton, adjpoll_trump, adjpoll_johnson, adjpoll_mcmullin, multiversions, url, poll_id, question_id, createdate datetime, timestamp datetime)')
conn.commit()

fivethirtyeight.to_sql('fivethirtyeight',conn, if_exists='replace')

# %%
df = pd.read_csv('https://projects.fivethirtyeight.com/polls-page/president_polls.csv')
df.columns
# Out:
# /Users/amandapotter/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (6,22,25,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['question_id', 'poll_id', 'cycle', 'state', 'pollster_id', 'pollster',
#        'sponsor_ids', 'sponsors', 'display_name', 'pollster_rating_id',
#        'pollster_rating_name', 'fte_grade', 'sample_size', 'population',
#        'population_full', 'methodology', 'office_type', 'seat_number',
#        'seat_name', 'start_date', 'end_date', 'election_date',
#        'sponsor_candidate', 'internal', 'partisan', 'tracking',
#        'nationwide_batch', 'ranked_choice_reallocated', 'created_at', 'notes',
#        'url', 'stage', 'race_id', 'answer', 'candidate_id', 'candidate_name',
#        'candidate_party', 'pct'],
#       dtype='object')

# %%
c.execute('DROP TABLE IF EXISTS trumpbiden')
c.execute('CREATE TABLE trumpbiden (question_id, poll_id, cycle, state, pollster_id, pollster, sponsor_ids, sponsors, display_name, pollster_rating_id, pollster_rating_name, fte_grade, sample_size, population, population_full, methodology, office_type, seat_number, seat_name, start_date, end_date, election_date, sponsor_candidate, internal, partisan, tracking, nationwide_batch, ranked_choice_reallocated, created_at, notes, url, stage, answer, candidate_name, candidate_party, pct)')
conn.commit()

df.to_sql('trumpbiden',conn, if_exists = 'replace')

# %%
df = pd.read_sql('''select * from trumpbiden limit 10;''',conn)
df
# Out:
#    index  question_id  poll_id  cycle         state  pollster_id  \
# 0      0       136283    72621   2020          Iowa          383
# 1      1       136283    72621   2020          Iowa          383
# 2      2       136322    72647   2020  Pennsylvania          461
# 3      3       136322    72647   2020  Pennsylvania          461
# 4      4       136322    72647   2020  Pennsylvania          461
# 5      5       136491    72722   2020       Florida          235
# 6      6       136491    72722   2020       Florida          235
# 7      7       136491    72722   2020       Florida          235
# 8      8       136338    72652   2020          None         1478
# 9      9       136338    72652   2020          None         1478
#
#                               pollster sponsor_ids       sponsors  \
# 0                Public Policy Polling        None           None
# 1                Public Policy Polling        None           None
# ...

# %%
df = pd.read_sql('''select * from fivethirtyeight limit 10;''',conn)
df
# Out:
#    index  cycle     branch        type                        matchup  \
# 0      0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1      1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2      2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3      3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4      4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 5      5   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 6      6   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 7      7   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 8      8   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 9      9   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
#
#   forecastdate         state   startdate     enddate  \
# 0      11/1/16          U.S.  10/25/2016  10/31/2016
# 1      11/1/16          U.S.  10/27/2016  10/30/2016
# ...

# %%
# %matplotlib inline

from pathlib import Path
import re

import numpy as np
import pandas as pd
import us

pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 50)

# %%
polls_2016_url = "http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv"
polls_2020_url = "https://projects.fivethirtyeight.com/polls-page/president_polls.csv"

polls_2016 = pd.read_csv(polls_2016_url)
polls_2020 = pd.read_csv(polls_2020_url)

polls_2016.head()
# Out:
# /Users/amandapotter/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (6,22,25,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  samplesize  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+      2220.0
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B     26574.0
# ...
