# %%
import pandas as pd

# %%
df = pd.read_csv('http://openelections.github.io/openelections-results-pa/raw/20121106__pa__general__precinct__raw.csv')
df.head()
# Out:
#                    updated_at                     id           start_date  \
# 0  2015-10-08 12:50:07.021000  pa-2012-11-06-general  2012-11-06 00:00:00
# 1  2015-10-08 12:50:07.021000  pa-2012-11-06-general  2012-11-06 00:00:00
# 2  2015-10-08 12:50:07.021000  pa-2012-11-06-general  2012-11-06 00:00:00
# 3  2015-10-08 12:50:07.021000  pa-2012-11-06-general  2012-11-06 00:00:00
# 4  2015-10-08 12:50:07.021000  pa-2012-11-06-general  2012-11-06 00:00:00
#
#               end_date election_type result_type  special     office  \
# 0  2012-11-06 00:00:00       general   certified    False  President
# 1  2012-11-06 00:00:00       general   certified    False  President
# 2  2012-11-06 00:00:00       general   certified    False  President
# 3  2012-11-06 00:00:00       general   certified    False  President
# 4  2012-11-06 00:00:00       general   certified    False  President
#
#    district  name_raw  ...  year  municipality  \
# 0         0       NaN  ...  2012   ABBOTTSTOWN
# ...
